# %% [markdown]
# Establish a relationship between:
# 1. price and house size
# 2. price and views
# 3. price and condition
#
# Overall Questions:
# 1. What is the biggest influence on price?
# 2. Are more expensive houses an easier sell?
#
# Increasing Views:
# 1. Views vs Price
# 2. Views vs Grade
# 3. Views cs condition
#
# House Specs:
# 1. Size of living space vs Size of lot
# 2. Floors vs living space
# 3. House condition vs grade
# 4. How recently revovated vs views

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
display(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.isna().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront        True
# view              True
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated      True
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.drop(columns='waterfront', axis=1, inplace= True)

# %%
df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 2      5631500400   2/25/2015   180000.0         2       1.00          770
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# 7      2008000270   1/15/2015   291850.0         3       1.50         1060
# 8      2414600126   4/15/2015   229500.0         3       1.00         1780
# 9      3793500160   3/12/2015   323000.0         3       2.50         1890
# 10     1736800520    4/3/2015   662500.0         3       2.50         3560
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# 6      1321400060 2014-06-27   257500.0         3       2.25         1715
# 7      2008000270 2015-01-15   291850.0         3       1.50         1060
# 8      2414600126 2015-04-15   229500.0         3       1.00         1780
# 9      3793500160 2015-03-12   323000.0         3       2.50         1890
# 10     1736800520 2015-04-03   662500.0         3       2.50         3560
# 11     9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %%
df.dropna(how='all')
df.dropna(subset=['view'], inplace=True)
df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# 6      1321400060 2014-06-27   257500.0         3       2.25         1715
# 8      2414600126 2015-04-15   229500.0         3       1.00         1780
# 9      3793500160 2015-03-12   323000.0         3       2.50         1890
# 10     1736800520 2015-04-03   662500.0         3       2.50         3560
# 11     9212900260 2014-05-27   468000.0         2       1.00         1160
# 12      114101516 2014-05-28   310000.0         3       1.00         1430
# ...

# %%
import seaborn as sns
plt.plot(df['view'].value_counts().sort_index())

# %%
plt.plot(df['condition'].value_counts().sort_index())

# %%
plt.plot(df['sqft_lot'].value_counts().sort_index())

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),
            vmin=-1,
            cmap='coolwarm')

# %%
plt.figure(figsize = (20,10))
correlation_matrix = df.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %%
abs(df_pred.corr()) > 0.75
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-1c917d5fde94> in <module>
# ----> 1 abs(df_pred.corr()) > 0.75
#
# NameError: name 'df_pred' is not defined

# %%
sns.barplot(x='condition', y='price', data=df)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.scatterplot(x='condition', y='price', data=df)

# %%
#sns.set(style="ticks", color_codes=True)
#df = sns.load_dataset("df")
sns.pairplot(data=df,x_vars="sqft_living",y_vars="bedrooms", height=4, aspect=2)

# %%
sns.scatterplot(data=df,x="bathrooms",y="bedrooms")

# %%
sns.pairplot(df, vars=['sqft_living', 'bedrooms', 'bathrooms'])

# %%
sns.pairplot(df, vars=['view', 'bathrooms', 'sqft_living'], diag_kind='kde')
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.scatterplot(x='sqft_above',y='sqft_living', data=df)

# %%
sns.pairplot(df, vars=['sqft_above', 'sqft_living', 'view'], kind ="reg", height=3)

# %%
plt.plot(df['zipcode'].value_counts().sort_index())

# %%
ax=sns.countplot(x="zipcode", data=df)

# %%
df.groupby(['zipcode','price']).sum()
df.head(10)
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13   221900.0         3       1.00         1180
# 1   6414100192 2014-12-09   538000.0         3       2.25         2570
# 2   5631500400 2015-02-25   180000.0         2       1.00          770
# 3   2487200875 2014-12-09   604000.0         4       3.00         1960
# 4   1954400510 2015-02-18   510000.0         3       2.00         1680
# 5   7237550310 2014-05-12  1230000.0         4       4.50         5420
# 6   1321400060 2014-06-27   257500.0         3       2.25         1715
# 8   2414600126 2015-04-15   229500.0         3       1.00         1780
# 9   3793500160 2015-03-12   323000.0         3       2.50         1890
# 10  1736800520 2015-04-03   662500.0         3       2.50         3560
#
#     sqft_lot  floors  view  condition  grade  sqft_above sqft_basement  \
# 0       5650     1.0   0.0          3      7        1180           0.0
# ...

# %%
df.groupby(['zipcode']).sum()
# Out:
#                     id        price  bedrooms  bathrooms  sqft_living  \
# zipcode
# 98001    1666116817479  100836348.0      1218     722.75       682726
# 98002     965327932213   46622523.0       662     366.00       323921
# 98003    1308770948990   82351158.0       940     573.25       540087
# 98004    1387233674187  429293105.0      1219     799.50       920530
# 98005     833594524651  136128669.0       647     407.25       446343
# 98006    2299236613809  427489400.0      1909    1271.00      1435921
# 98007     627544734650   87032817.0       538     306.50       307670
# 98008    1300301832588  182712788.0      1057     591.00       603765
# 98010     387919540667   42366599.0       329     202.75       213759
# 98011     834478542276   94996286.0       688     441.75       436524
# 98014     525841296073   56496522.0       372     254.00       262628
# 98019     596204394319   80714862.0       639     435.25       412596
# ...

# %%
sns.pairplot(df, vars=['zipcode', 'price', 'view'], kind ="reg", height=3)

# %%
sns.barplot(x='zipcode',y='sqft_living', data=df)

# %%
plt.figure(figsize = (20,10))
with sns.axes_style('white'):
    sns.jointplot("zipcode", "sqft_living", data=df, kind='kde')

# %%
zip_grade_df = df.groupby(['zipcode', 'grade']).sum()
zip_grade_df
# Out:
#                          id       price  bedrooms  bathrooms  sqft_living  \
# zipcode grade
# 98001   5       40344825240   1451700.0        21      10.50         9950
#         6      132042556590   6194569.0        84      42.25        40357
#         7      887109592007  51201418.0       698     396.50       355113
#         8      387709458566  25721938.0       282     185.00       175742
#         9      186807885705  13549823.0       114      75.50        85171
#         10      32102499371   2716900.0        19      13.00        16393
# 98002   5       81970402641   1912945.0        26      13.75        11990
#         6      249826191259   9989200.0       155      65.75        65180
#         7      559575136096  30988128.0       432     256.25       217927
#         8       73956202217   3732250.0        49      30.25        28824
# 98003   6       37386320995   2050600.0        28      11.50        13420
# ...

# %%
plt.figure(figsize = (20,10))
with sns.axes_style('white'):
    sns.jointplot("zipcode", "price", data=df, kind='kde')

# %%
sns.jointplot("bathrooms", "sqft_living", data= df, kind="hex", color="m")

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.sqft_living, df.bathrooms, cmap=cmap, n_levels=60, shade=True)

# %%
f, ax = plt.subplots(figsize=(20,10))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.sqft_living, df.sqft_living15, cmap=cmap, n_levels=60, shade=True)

# %%
f, ax = plt.subplots(figsize=(10,10))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.zipcode, df.grade, cmap=cmap, n_levels=60, shade=True)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
plt.scatter(df.sqft_living, df.bathrooms)
plt.title('linearity check')
plt.show()

# %%
plt.scatter(df.sqft_living, df.sqft_living15)
plt.title('linearity check')
plt.show()

# %%
plt.scatter(df.sqft_lot, df.sqft_lot15)
plt.title('linearity check')
plt.show()

# %%
df.plot.kde()
plt.title('distribution check for sqft_living and bathrooms')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-f3c944a5a4c7> in <module>
# ----> 1 df.plot.kde()
#       2 plt.title('distribution check for sqft_living and bathrooms')
#       3 plt.show()
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwds)
#    3308     })
#    3309     def kde(self, bw_method=None, ind=None, **kwds):
# -> 3310         return self(kind='kde', bw_method=bw_method, ind=ind, **kwds)
#    3311
#    3312     density = kde
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
f= 'bathrooms~sqft_living'
model=ols(formula=f, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              bathrooms   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                 2.859e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:12:01   Log-Likelihood:                -15789.
# No. Observations:               21534   AIC:                         3.158e+04
# Df Residuals:                   21532   BIC:                         3.160e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.7997      0.009     94.018      0.000       0.783       0.816
# ...

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "sqft_living", fig=fig)
plt.show()

# %%
import scipy.stats as stats
residuals = model.resid
fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
plt.figure(figsize=(20,10))
features = ['sqft_living', 'view']
target = df['price']

for i, col in enumerate(features):
    plt.subplot(1, len(features), i+1)
    x= df[col]
    y= target
    plt.scatter(x,y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('price')

# %%
X = pd.DataFrame(np.c_[df['sqft_living'], df['view']], columns = ['sqft_living', 'view'])
Y = df['price']

# %%
x = df['sqft_living']
y = df['price']
X = sm.add_constant(x)
model = sm.OLS(y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                 2.087e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        14:05:53   Log-Likelihood:            -2.9912e+05
# No. Observations:               21534   AIC:                         5.982e+05
# Df Residuals:                   21532   BIC:                         5.983e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.215e+04   4404.521     -9.570      0.000   -5.08e+04   -3.35e+04
# ...

# %%
x = df['sqft_living15']
y = df['price']
X = sm.add_constant(x)
model = sm.OLS(y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.343
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                 1.122e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        14:11:06   Log-Likelihood:            -3.0190e+05
# No. Observations:               21534   AIC:                         6.038e+05
# Df Residuals:                   21532   BIC:                         6.038e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
x = df['sqft_lot']
y = df['price']
X = sm.add_constant(x)
model = sm.OLS(y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     177.2
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):           2.90e-40
# Time:                        14:11:19   Log-Likelihood:            -3.0633e+05
# No. Observations:               21534   AIC:                         6.127e+05
# Df Residuals:                   21532   BIC:                         6.127e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.28e+05   2644.447    199.663      0.000    5.23e+05    5.33e+05
# ...

# %%
x = df['sqft_lot15']
y = df['price']
X = sm.add_constant(x)
model = sm.OLS(y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     150.1
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):           2.20e-34
# Time:                        14:11:30   Log-Likelihood:            -3.0634e+05
# No. Observations:               21534   AIC:                         6.127e+05
# Df Residuals:                   21532   BIC:                         6.127e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.258e+05   2744.555    191.583      0.000     5.2e+05    5.31e+05
# ...

# %%
#Assign feature columns as list
feature_cols = ['sqft_living', 'grade']

#Assign X as a subset of the data set containing only feature columns
X = df[feature_cols]

#Assign to Y the target varieable
y = df['price']

# %%
#splitting X and y into training and testing data sets 
from sklearn.model_selection import train_test_split

#Assign variables to capture train test split output
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#import SK learn linear regression
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

#fit model to training data
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#print y intercept
print(linreg.intercept_)

#print beta coefficient
print(linreg.coef_)

#pair features and coefficients together
zip(feature_cols, linreg.coef_)
# Out:
# -602372.4695812141
# [  184.16647183 99022.6422296 ]

# %%
#predict y values using the test data from X
y_pred = linreg.predict(X_test)

# %%
#import metrics library
from sklearn import metrics

#Calculate error using RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 247435.0746815629

# %%
f= 'price~sqft_living'
model=ols(formula=f, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.492
# Method:                 Least Squares   F-statistic:                 2.087e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:57:22   Log-Likelihood:            -2.9912e+05
# No. Observations:               21534   AIC:                         5.982e+05
# Df Residuals:                   21532   BIC:                         5.983e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.215e+04   4404.521     -9.570      0.000   -5.08e+04   -3.35e+04
# ...

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "sqft_living", fig=fig)
plt.show()
